# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Ziyue Yin"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# Quiz 10, STATS102 Fall 2022 Session 1, Duke Kunshan University, Sep 8th
# ![](dku.jpg)
# For this problem set, we'll be using the Jupyter notebook:
# ![](jupyter.png)

# %% [markdown]
# load the census data from http://census.ire.org/data/bulkdata.html (census.csv), calcualte and return a list of top 5 state names ordered in descending way by the average county population in that state. The populations for all counties in each state are listed in column CENSUS2010POP.

# %%
import numpy as np
import pandas as pd
def myfunction():
    df = pd.read_csv('census.csv')
    # YOUR CODE HERE
    df = pd.read_csv('census.csv')
    return df.groupby('STNAME').mean().sort_values(by=['CENSUS2010POP'],ascending=False).head(5).index

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('census.csv')
df.groupby('STNAME').mean().sort_values(by=['CENSUS2010POP'],ascending=False).head(5).index
# Out:
# Index(['California', 'District of Columbia', 'Massachusetts', 'Connecticut',
#        'Arizona'],
#       dtype='object', name='STNAME')

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('census.csv')
df.groupby('STNAME')['CENSUS2010POP'].mean().sort_values(ascending=False).head(5).index
# Out:
# Index(['California', 'District of Columbia', 'Massachusetts', 'Connecticut',
#        'Arizona'],
#       dtype='object', name='STNAME')

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('census.csv')
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         50       3         6      1       1  Alabama     Autauga County
# 1         50       3         6      1       3  Alabama     Baldwin County
# 2         50       3         6      1       5  Alabama     Barbour County
# 3         50       3         6      1       7  Alabama        Bibb County
# 4         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3137      50       4         8     56      37  Wyoming  Sweetwater County
# 3138      50       4         8     56      39  Wyoming       Teton County
# 3139      50       4         8     56      41  Wyoming       Uinta County
# 3140      50       4         8     56      43  Wyoming    Washakie County
# 3141      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 0             54571              54571            54660  ...
# 1            182265             182265           183193  ...
# 2             27457              27457            27341  ...
# 3             22915              22919            22861  ...
# 4             57322              57322            57373  ...
# ...             ...                ...              ...  ...
# 3137          43806              43806            43593  ...
# 3138          21294              21294            21297  ...
# 3139          21118              21118            21102  ...
# 3140           8533               8533             8545  ...
# 3141           7208               7208             7181  ...
#
#       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0             7.242091         -2.915927         -3.012349          2.265971
# 1            14.832960         17.647293         21.845705         19.243286
# 2            -4.728132         -2.500690         -7.056824         -3.904217
# 3            -5.527043         -5.068871         -6.201001         -0.177537
# 4             1.807375         -1.177622         -1.748766         -2.062535
# ...                ...               ...               ...               ...
# 3137          1.072643         16.243199         -5.339774        -14.252889
# 3138         -1.589565          0.972695         19.525929         14.143021
# 3139        -17.755986         -4.916350         -6.902954        -14.215862
# 3140        -11.637475         -0.827815         -2.013502        -17.781491
# 3141        -11.752361         -8.040059         12.372583          1.533635
#
#       RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# 0            -2.530799     7.606016    -2.626146    -2.722002     2.592270
# 1            17.197872    15.844176    18.559627    22.727626    20.317142
# 2           -10.543299    -4.874741    -2.758113    -7.167664    -3.978583
# 3             0.177258    -5.088389    -4.363636    -5.403729     0.754533
# 4            -1.369970     1.859511    -0.848580    -1.402476    -1.577232
# ...                ...          ...          ...          ...          ...
# 3137        -14.248864     1.255221    16.243199    -5.295460   -14.075283
# 3138         -0.564849     0.654527     2.408578    21.160658    16.308671
# 3139        -12.127022   -18.136812    -5.536861    -7.521840   -14.740608
# 3140          1.682288   -11.990126    -1.182592    -2.250385   -18.020168
# 3141          6.935294   -12.032179    -8.040059    12.372583     1.533635
#
#       RNETMIG2015
# 0       -2.187333
# 1       18.293499
# 2      -10.543299
# 3        1.107861
# 4       -0.884411
# ...           ...
# 3137   -14.070195
# 3138     1.520747
# 3139   -12.606351
# 3140     1.441961
# 3141     6.935294
#
# [3142 rows x 100 columns]

# %%
import numpy as np
import pandas as pd
names=myfunction()
assert names[0]=='California'
assert names[1]=='District of Columbia'
assert names[2]=='Massachusetts'
assert names[3]=='Connecticut'
assert names[4]=='Arizona'
