# %% [markdown]
# #### Notes for STATS102, Session 1, Week 1, Aug24th, Lecture, part 2

# %%
n = 5
while n > 0 :
    print(n)
    n = n - 1
    
    
print('Done!')
print(n)
# Out:
# 5
# 4
# 3
# 2
# 1
# Done!
# 0

# %%
n = 5
while n > 0 :
    print('DKU')
print('Done!')
# Out:
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# DKU
# ...

# %%
while True:
    line = input('> ')
    if line == 'done' :
        break
    print(line)
print('finish!')
# Out:
# > k
# k
# > l
# l
# > k
# k
# > n
# n
# > done
# finish!

# %% [markdown]
# review logic in P4E slides
# ![](break.png)

# %% [markdown]
# review the logic in P4E slides
# ![](continue.png)

# %%
while True:
    line = input('> ')
    if line[0] == '#' :
        continue
    if line == 'done' :
        break
    print(line)
print('Finish!')
# Out:
# > #
# > k
# k
# > lo
# lo
# > j]\ki
# j]\ki
# > hjuhj
# hjuhj
# > done
# Finish!

# %%
line='abcd'
line[1]
# Out:
# 'b'

# %%
for i in range(6) :
    print(i)
print('finished!')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# finished!

# %% [markdown]
# review the logic in P4E slides
# ![](definiteloop.png)

# %%
friends = ['Derek', 'Gary', 'Julia']
for friend in friends : 
    print('Happy New Year:', friend)
print('Done!')
# Out:
# Happy New Year: Derek
# Happy New Year: Gary
# Happy New Year: Julia
# Done!

# %%
print('Before')
for thing in [9, 41, 12, 3, 74, 15] :
     print(thing)
print('After')
# Out:
# Before
# 9
# 41
# 12
# 3
# 74
# 15
# After

# %%
smallest_so_far = None #largest_so_far = None       
print('Before', smallest_so_far)
for the_num in [9, 41, 12, 3, 74, 15] :
    if(smallest_so_far==None):
        smallest_so_far=the_num
    else:
        if the_num < smallest_so_far :
            smallest_so_far = the_num
    print('smallest_so_far',smallest_so_far, 'current num',the_num)
print('After', smallest_so_far)
# Out:
# Before None
# smallest_so_far 9 current num 9
# smallest_so_far 9 current num 41
# smallest_so_far 9 current num 12
# smallest_so_far 3 current num 3
# smallest_so_far 3 current num 74
# smallest_so_far 3 current num 15
# After 3

# %%
smallest_so_far = 9       
print('Before', smallest_so_far)
for the_num in [10,11,12] :
    if the_num < smallest_so_far :
            smallest_so_far = the_num
    print('smallest_so_far',smallest_so_far, 'current num',the_num)
print('After', smallest_so_far)
# Out:
# Before 9
# smallest_so_far 9 current num 10
# smallest_so_far 9 current num 11
# smallest_so_far 9 current num 12
# After 9

# %% [markdown]
# how to find the smallest number?

# %%
mysum = 0
print('Before', mysum)
for number in [9, 41, 12, 3, 74, 15] :
    mysum = mysum + number
    print(mysum, number)
print('After', mysum)
# Out:
# Before 0
# 9 9
# 50 41
# 62 12
# 65 3
# 139 74
# 154 15
# After 154

# %% [markdown]
# we can do the average calculation based on the above code

# %%
#Filtering in a Loop
print('Before') 
for value in [9, 41, 12, 3, 74, 15] :
    if value > 20:
        print('Large number',value)
print('After')
# Out:
# Before
# Large number 41
# Large number 74
# After

# %%
found = False
print('Before', found)
for value in [9, 41, 12, 3, 74, 15] : 
    if value == 15 :
        found = True
        break
    print(found, value)
print('After', found)
# Out:
# Before False
# False 9
# False 41
# False 12
# False 3
# False 74
# After True

# %%
3 in [9, 41, 12, 3, 74, 15]
# Out:
# True

# %%
max([9, 41, 12, 3, 74, 15])
# Out:
# 74

# %%
min([9, 41, 12, 3, 74, 15])
# Out:
# 3

# %%
sum([9, 41, 12, 3, 74, 15])
# Out:
# 154

# %%
a=[9, 41, 12, 3, 74, 15]

# %%
a.append(-1)
a
# Out:
# [9, 41, 12, 3, 74, 15, -1]

# %%
len(a)
# Out:
# 7

# %%
import numpy as np
np.mean([9, 41, 12, 3, 74, 15])
# Out:
# 25.666666666666668

# %%
sum([9, 41, 12, 3, 74, 15])/len([9, 41, 12, 3, 74, 15])
# Out:
# 25.666666666666668

# %%
a=[1,2,3]
b=a
b=['a','b']
print(a)
# Out:
# [1, 2, 3]

# %%
a=[1,2,3]
b=a
b.append(4)
print(a)
# Out:
# [1, 2, 3, 4]
