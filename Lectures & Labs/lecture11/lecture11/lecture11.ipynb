# %% [markdown]
# # Notes for STATS102, Session 1, Sep 8th, Lecture
# partial materials are from the text book
# Python Data Science Handbook: Essential Tools for Working with Data, by Jake VanderPlas, O'Reilly Media; 1 edition (December 10, 2016), ISBN-13: 978-1491912058, full text and code freely available at https://jakevdp.github.io/PythonDataScienceHandbook/.

# %%
import numpy as np
import pandas as pd
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

# %%
ser = pd.Series(np.random.rand(5))
ser
# Out:
# 0    0.682779
# 1    0.298928
# 2    0.500008
# 3    0.392131
# 4    0.679075
# dtype: float64

# %%
ser.sum()
# Out:
# 2.552920955238781

# %%
ser.mean()
# Out:
# 0.5105841910477562

# %%
df = pd.DataFrame({'A': np.random.rand(5),
                   'B': np.random.rand(5)})
df
# Out:
#           A         B
# 0  0.442108  0.826817
# 1  0.473382  0.218281
# 2  0.814319  0.818428
# 3  0.663995  0.193393
# 4  0.379229  0.998853

# %%
df.mean()
# Out:
# A    0.554606
# B    0.611154
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0    0.634462
# 1    0.345832
# 2    0.816373
# 3    0.428694
# 4    0.689041
# dtype: float64

# %%
import seaborn as sns
planets = sns.load_dataset('planets')
planets.shape
# Out:
# (1035, 6)

# %%
sns.load_dataset?

# %%
sns.get_dataset_names()
# Out:
# C:\Users\ml442\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\ml442\AppData\Local\Continuum\anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
planets.head(3)
# Out:
#             method  number  orbital_period  mass  distance  year
# 0  Radial Velocity       1         269.300  7.10     77.40  2006
# 1  Radial Velocity       1         874.774  2.21     56.95  2008
# 2  Radial Velocity       1         763.000  2.60     19.84  2011

# %%
planets.tail(3)
# Out:
#        method  number  orbital_period  mass  distance  year
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
planets
# Out:
#                method  number  orbital_period    mass  distance  year
# 0     Radial Velocity       1      269.300000   7.100     77.40  2006
# 1     Radial Velocity       1      874.774000   2.210     56.95  2008
# 2     Radial Velocity       1      763.000000   2.600     19.84  2011
# 3     Radial Velocity       1      326.030000  19.400    110.62  2007
# 4     Radial Velocity       1      516.220000  10.500    119.47  2009
# 5     Radial Velocity       1      185.840000   4.800     76.39  2008
# 6     Radial Velocity       1     1773.400000   4.640     18.15  2002
# 7     Radial Velocity       1      798.500000     NaN     21.41  1996
# 8     Radial Velocity       1      993.300000  10.300     73.10  2008
# 9     Radial Velocity       2      452.800000   1.990     74.79  2010
# 10    Radial Velocity       2      883.000000   0.860     74.79  2010
# 11    Radial Velocity       1      335.100000   9.880     39.43  2009
# ...

# %%
planets.dropna()
# Out:
#               method  number  orbital_period     mass  distance  year
# 0    Radial Velocity       1      269.300000   7.1000     77.40  2006
# 1    Radial Velocity       1      874.774000   2.2100     56.95  2008
# 2    Radial Velocity       1      763.000000   2.6000     19.84  2011
# 3    Radial Velocity       1      326.030000  19.4000    110.62  2007
# 4    Radial Velocity       1      516.220000  10.5000    119.47  2009
# 5    Radial Velocity       1      185.840000   4.8000     76.39  2008
# 6    Radial Velocity       1     1773.400000   4.6400     18.15  2002
# 8    Radial Velocity       1      993.300000  10.3000     73.10  2008
# 9    Radial Velocity       2      452.800000   1.9900     74.79  2010
# 10   Radial Velocity       2      883.000000   0.8600     74.79  2010
# 11   Radial Velocity       1      335.100000   9.8800     39.43  2009
# 12   Radial Velocity       1      479.100000   3.8800     97.28  2008
# ...

# %%
planets.dropna().describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %%
planets.dropna().describe().loc['count']
# Out:
# number            498.0
# orbital_period    498.0
# mass              498.0
# distance          498.0
# year              498.0
# Name: count, dtype: float64

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data': range(6)}, columns=['data','key'])
df
# Out:
#    data key
# 0     0   A
# 1     1   B
# 2     2   C
# 3     3   A
# 4     4   B
# 5     5   C

# %%
df.groupby('key').describe()
# Out:
#      data
#     count mean      std  min   25%  50%   75%  max
# key
# A     2.0  1.5  2.12132  0.0  0.75  1.5  2.25  3.0
# B     2.0  2.5  2.12132  1.0  1.75  2.5  3.25  4.0
# C     2.0  3.5  2.12132  2.0  2.75  3.5  4.25  5.0

# %%
df.groupby('key').mean()
# Out:
#      data
# key
# A     1.5
# B     2.5
# C     3.5

# %%
df.groupby('key').count()
# Out:
#      data
# key
# A       2
# B       2
# C       2

# %%
planets
# Out:
#                method  number  orbital_period    mass  distance  year
# 0     Radial Velocity       1      269.300000   7.100     77.40  2006
# 1     Radial Velocity       1      874.774000   2.210     56.95  2008
# 2     Radial Velocity       1      763.000000   2.600     19.84  2011
# 3     Radial Velocity       1      326.030000  19.400    110.62  2007
# 4     Radial Velocity       1      516.220000  10.500    119.47  2009
# 5     Radial Velocity       1      185.840000   4.800     76.39  2008
# 6     Radial Velocity       1     1773.400000   4.640     18.15  2002
# 7     Radial Velocity       1      798.500000     NaN     21.41  1996
# 8     Radial Velocity       1      993.300000  10.300     73.10  2008
# 9     Radial Velocity       2      452.800000   1.990     74.79  2010
# 10    Radial Velocity       2      883.000000   0.860     74.79  2010
# 11    Radial Velocity       1      335.100000   9.880     39.43  2009
# ...

# %%
planets.groupby('method').mean()
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# Transit                        1.954660       21.102073  1.470000
# Transit Timing Variations      2.250000       79.783500       NaN
#
#                                   distance         year
# method
# Astrometry                       17.875000  2011.500000
# Eclipse Timing Variations       315.360000  2010.000000
# ...

# %%
planets.dropna().groupby('method').mean()
# Out:
#                    number  orbital_period      mass    distance         year
# method
# Radial Velocity  1.736419      837.454878  2.511411   51.814829  2007.366197
# Transit          1.000000        2.703390  1.470000  178.000000  2013.000000

# %%
planets[planets['method']=='Eclipse Timing Variations']['orbital_period'].mean()
# Out:
# 4751.644444444445

# %%
planets.mean()
# Out:
# number               1.785507
# orbital_period    2002.917596
# mass                 2.638161
# distance           264.069282
# year              2009.070531
# dtype: float64

# %%
planets[planets['method']=='Eclipse Timing Variations']['orbital_period'].mean()
# Out:
# 4751.644444444445

# %%
for (method, group) in planets.groupby('method'):
    print("{0} shape={1}".format(method, group.shape))
# Out:
# Astrometry shape=(2, 6)
# Eclipse Timing Variations shape=(9, 6)
# Imaging shape=(38, 6)
# Microlensing shape=(23, 6)
# Orbital Brightness Modulation shape=(3, 6)
# Pulsar Timing shape=(5, 6)
# Pulsation Timing Variations shape=(1, 6)
# Radial Velocity shape=(553, 6)
# Transit shape=(397, 6)
# Transit Timing Variations shape=(4, 6)

# %%
method
# Out:
# 'Transit Timing Variations'

# %%
group
# Out:
#                         method  number  orbital_period  mass  distance  year
# 680  Transit Timing Variations       2        160.0000   NaN    2119.0  2011
# 736  Transit Timing Variations       2         57.0110   NaN     855.0  2012
# 749  Transit Timing Variations       3             NaN   NaN       NaN  2014
# 813  Transit Timing Variations       2         22.3395   NaN     339.0  2013

# %%
planets.groupby('method').mean()
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# Transit                        1.954660       21.102073  1.470000
# Transit Timing Variations      2.250000       79.783500       NaN
#
#                                   distance         year
# method
# Astrometry                       17.875000  2011.500000
# Eclipse Timing Variations       315.360000  2010.000000
# ...

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data1': range(6),
                   'data2': np.random.randint(0, 10, 6)},
                   columns = ['key', 'data1', 'data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      7
# 2   C      2      4
# 3   A      3      5
# 4   B      4      4
# 5   C      5      4

# %%
df.groupby('key').aggregate([np.min, np.mean, np.max])#aggregate(), filter(), transform(), and apply()
# Out:
#     data1           data2
#      amin mean amax  amin mean amax
# key
# A       0  1.5    3     2  5.0    8
# B       1  2.5    4     1  3.0    5
# C       2  3.5    5     1  3.5    6

# %%
df.groupby('key').aggregate({'data1': 'min',
                             'data2': 'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      4

# %%
def filter_func(x):
    return x['data2'].std() > 3

display('df', "df.groupby('key').std()", "df.groupby('key').filter(filter_func)")
# Out:
# df
#   key  data1  data2
# 0   A      0      1
# 1   B      1      9
# 2   C      2      4
# 3   A      3      8
# 4   B      4      4
# 5   C      5      8
#
# df.groupby('key').std()
#        data1     data2
# key
# A    2.12132  4.949747
# B    2.12132  3.535534
# C    2.12132  2.828427
#
# df.groupby('key').filter(filter_func)
#   key  data1  data2
# 0   A      0      1
# 1   B      1      9
# 3   A      3      8
# 4   B      4      4

# %%
df[df['data2']>2]
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      7
# 2   C      2      4
# 3   A      3      5
# 4   B      4      4
# 5   C      5      4

# %%
display('df', "df.groupby('key').std()", "df.groupby('key').filter(lambda x: x['data2'].std()>3)")
# Out:
# df
#   key  data1  data2
# 0   A      0      5
# 1   B      1      7
# 2   C      2      4
# 3   A      3      5
# 4   B      4      4
# 5   C      5      4
#
# df.groupby('key').std()
#        data1    data2
# key
# A    2.12132  0.00000
# B    2.12132  2.12132
# C    2.12132  0.00000
#
# df.groupby('key').filter(lambda x: x['data2'].std()>3)
# Empty DataFrame
# Columns: [key, data1, data2]
# Index: []

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      7
# 2   C      2      4
# 3   A      3      5
# 4   B      4      4
# 5   C      5      4

# %%
df.groupby('key').transform(lambda x: x - x.mean())
# Out:
#    data1  data2
# 0   -1.5    0.0
# 1   -1.5    1.5
# 2   -1.5    0.0
# 3    1.5    0.0
# 4    1.5   -1.5
# 5    1.5    0.0

# %%
def norm_by_data2(x):
    # x is a DataFrame of group values
    x['data1'] = x['data1'] / x['data2'].sum()
    return x

display('df', "df.groupby('key').apply(norm_by_data2)")
# Out:
# df
#   key  data1  data2
# 0   A      0      5
# 1   B      1      7
# 2   C      2      4
# 3   A      3      5
# 4   B      4      4
# 5   C      5      4
#
# df.groupby('key').apply(norm_by_data2)
#   key     data1  data2
# 0   A  0.000000      5
# 1   B  0.090909      7
# 2   C  0.250000      4
# 3   A  0.300000      5
# 4   B  0.363636      4
# 5   C  0.625000      4

# %%
L = [0, 1, 0, 1, 2, 0]
display('df', 'df.groupby(L).sum()')
# Out:
# df
#   key  data1  data2
# 0   A      0      7
# 1   B      1      8
# 2   C      2      6
# 3   A      3      4
# 4   B      4      2
# 5   C      5      6
#
# df.groupby(L).sum()
#    data1  data2
# 0      7     19
# 1      4     12
# 2      4      2

# %%
display('df', "df.groupby(df['key']).sum()")
# Out:
# df
#   key  data1  data2
# 0   A      0      7
# 1   B      1      8
# 2   C      2      6
# 3   A      3      4
# 4   B      4      2
# 5   C      5      6
#
# df.groupby(df['key']).sum()
#      data1  data2
# key
# A        3     11
# B        5     10
# C        7     12

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      7
# 2   C      2      4
# 3   A      3      5
# 4   B      4      4
# 5   C      5      4

# %%
df2 = df.set_index('key')
df2
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      4
# A        3      5
# B        4      4
# C        5      4

# %%
df2.groupby(str.lower).mean()
# Out:
#    data1  data2
# a    1.5    5.0
# b    2.5    5.5
# c    3.5    4.0

# %%
df2 = df.set_index('key')
mapping = {'A': 'vowel', 'B': 'consonant', 'C': 'consonant'}
display('df2', 'df2.groupby(mapping).sum()')
# Out:
# df2
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      4
# A        3      5
# B        4      4
# C        5      4
#
# df2.groupby(mapping).sum()
#            data1  data2
# consonant     12     19
# vowel          3     10

# %%
display('df2', "df2.groupby(str).mean()")
# Out:
# df2
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      4
# A        3      5
# B        4      4
# C        5      4
#
# df2.groupby(str).mean()
#    data1  data2
# A    1.5    5.0
# B    2.5    5.5
# C    3.5    4.0

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data1': range(6),
                   'data2': np.random.randint(0, 10, 6)},
                   columns = ['key', 'data1', 'data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      2
# 1   B      1      5
# 2   C      2      9
# 3   A      3      7
# 4   B      4      0
# 5   C      5      9

# %%
df.groupby(['key','data1'])['data2'].mean()
# Out:
# key  data1
# A    0        2
#      3        7
# B    1        5
#      4        0
# C    2        9
#      5        9
# Name: data2, dtype: int32

# %%
decade = 10 * (planets['year'] // 10)
decade = decade.astype(str) + 's'
decade.name = 'decade'
decade
# Out:
# 0       2000s
# 1       2000s
# 2       2010s
# 3       2000s
# 4       2000s
# 5       2000s
# 6       2000s
# 7       1990s
# 8       2000s
# 9       2010s
# 10      2010s
# 11      2000s
# 12      2000s
# 13      1990s
# 14      2000s
# 15      2000s
# 16      1990s
# 17      1990s
# 18      2000s
# 19      2000s
# 20      2010s
# 21      2000s
# 22      2000s
# 23      2000s
# 24      2000s
# 25      1990s
# 26      2010s
# 27      2000s
# 28      2010s
# 29      2000s
#         ...
# 1005    2010s
# 1006    2010s
# 1007    2010s
# 1008    2010s
# 1009    2010s
# 1010    2010s
# 1011    2010s
# 1012    2010s
# 1013    2010s
# 1014    2010s
# 1015    2010s
# 1016    2010s
# 1017    2010s
# 1018    2010s
# 1019    2010s
# 1020    2010s
# 1021    2010s
# 1022    2010s
# 1023    2010s
# 1024    2010s
# 1025    2010s
# 1026    2010s
# 1027    2010s
# 1028    2010s
# 1029    2010s
# 1030    2000s
# 1031    2000s
# 1032    2000s
# 1033    2000s
# 1034    2000s
# ...

# %%
planets.groupby(['method', decade]).count()['number'].unstack().fillna(0)
# Out:
# decade                         1980s  1990s  2000s  2010s
# method
# Astrometry                       0.0    0.0    0.0    2.0
# Eclipse Timing Variations        0.0    0.0    3.0    6.0
# Imaging                          0.0    0.0   20.0   18.0
# Microlensing                     0.0    0.0   10.0   13.0
# Orbital Brightness Modulation    0.0    0.0    0.0    3.0
# Pulsar Timing                    0.0    3.0    1.0    1.0
# Pulsation Timing Variations      0.0    0.0    1.0    0.0
# Radial Velocity                  1.0   28.0  309.0  215.0
# Transit                          0.0    0.0   62.0  335.0
# Transit Timing Variations        0.0    0.0    0.0    4.0

# %%
planets.groupby(['method', decade]).count()['number'].unstack().fillna(0)
# Out:
# decade                         1980s  1990s  2000s  2010s
# method
# Astrometry                       0.0    0.0    0.0    2.0
# Eclipse Timing Variations        0.0    0.0    3.0    6.0
# Imaging                          0.0    0.0   20.0   18.0
# Microlensing                     0.0    0.0   10.0   13.0
# Orbital Brightness Modulation    0.0    0.0    0.0    3.0
# Pulsar Timing                    0.0    3.0    1.0    1.0
# Pulsation Timing Variations      0.0    0.0    1.0    0.0
# Radial Velocity                  1.0   28.0  309.0  215.0
# Transit                          0.0    0.0   62.0  335.0
# Transit Timing Variations        0.0    0.0    0.0    4.0

# %%
planets.groupby(['method', decade]).count()['number'].unstack().fillna(0)
# Out:
# decade                         1980s  1990s  2000s  2010s
# method
# Astrometry                       0.0    0.0    0.0    2.0
# Eclipse Timing Variations        0.0    0.0    3.0    6.0
# Imaging                          0.0    0.0   20.0   18.0
# Microlensing                     0.0    0.0   10.0   13.0
# Orbital Brightness Modulation    0.0    0.0    0.0    3.0
# Pulsar Timing                    0.0    3.0    1.0    1.0
# Pulsation Timing Variations      0.0    0.0    1.0    0.0
# Radial Velocity                  1.0   28.0  309.0  215.0
# Transit                          0.0    0.0   62.0  335.0
# Transit Timing Variations        0.0    0.0    0.0    4.0

# %%
decade = 10 * (planets['year'] // 10)
decade = decade.astype(str) + 's'
decade.name = 'decade'
planets.groupby(['method', decade]).count()
# Out:
#                                       number  orbital_period  mass  distance  \
# method                        decade
# Astrometry                    2010s        2               2     0         2
# Eclipse Timing Variations     2000s        3               3     1         2
#                               2010s        6               6     1         2
# Imaging                       2000s       20               9     0        16
#                               2010s       18               3     0        16
# Microlensing                  2000s       10               5     0         0
#                               2010s       13               2     0        10
# Orbital Brightness Modulation 2010s        3               3     0         2
# Pulsar Timing                 1990s        3               3     0         0
#                               2000s        1               1     0         0
#                               2010s        1               1     0         1
# ...

# %%
planets.groupby(['method', decade])['number'].count().unstack()
# Out:
# decade                         1980s  1990s  2000s  2010s
# method
# Astrometry                       NaN    NaN    NaN    2.0
# Eclipse Timing Variations        NaN    NaN    3.0    6.0
# Imaging                          NaN    NaN   20.0   18.0
# Microlensing                     NaN    NaN   10.0   13.0
# Orbital Brightness Modulation    NaN    NaN    NaN    3.0
# Pulsar Timing                    NaN    3.0    1.0    1.0
# Pulsation Timing Variations      NaN    NaN    1.0    NaN
# Radial Velocity                  1.0   28.0  309.0  215.0
# Transit                          NaN    NaN   62.0  335.0
# Transit Timing Variations        NaN    NaN    NaN    4.0

# %%
titanic = sns.load_dataset('titanic')
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.groupby(['sex'])

# %%
titanic.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby(['sex','class'])['survived'].mean().unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # pivot_table

# %%
titanic.pivot_table('survived', index='sex', columns='class')
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table('fare', index='sex', columns='class',aggfunc=np.sum)
# Out:
# class       First     Second      Third
# sex
# female  9975.8250  1669.7292  2321.1086
# male    8201.5875  2132.1125  4393.5865

# %%
titanic.groupby(['sex','class'])['fare'].sum().unstack()
# Out:
# class       First     Second      Third
# sex
# female  9975.8250  1669.7292  2321.1086
# male    8201.5875  2132.1125  4393.5865

# %%
titanic.pivot_table?

# %%
titanic.groupby(['sex','class'])['survived'].mean().unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
age = pd.cut(titanic['age'], [0, 18, 80])
age
# Out:
# 0      (18, 80]
# 1      (18, 80]
# 2      (18, 80]
# 3      (18, 80]
# 4      (18, 80]
# 5           NaN
# 6      (18, 80]
# 7       (0, 18]
# 8      (18, 80]
# 9       (0, 18]
# 10      (0, 18]
# 11     (18, 80]
# 12     (18, 80]
# 13     (18, 80]
# 14      (0, 18]
# 15     (18, 80]
# 16      (0, 18]
# 17          NaN
# 18     (18, 80]
# 19          NaN
# 20     (18, 80]
# 21     (18, 80]
# 22      (0, 18]
# 23     (18, 80]
# 24      (0, 18]
# 25     (18, 80]
# 26          NaN
# 27     (18, 80]
# 28          NaN
# 29          NaN
#          ...
# 861    (18, 80]
# 862    (18, 80]
# 863         NaN
# 864    (18, 80]
# 865    (18, 80]
# 866    (18, 80]
# 867    (18, 80]
# 868         NaN
# 869     (0, 18]
# 870    (18, 80]
# 871    (18, 80]
# 872    (18, 80]
# 873    (18, 80]
# 874    (18, 80]
# 875     (0, 18]
# 876    (18, 80]
# 877    (18, 80]
# 878         NaN
# 879    (18, 80]
# 880    (18, 80]
# 881    (18, 80]
# 882    (18, 80]
# 883    (18, 80]
# 884    (18, 80]
# ...

# %%
titanic.pivot_table('survived', ['sex', age], 'class')
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %%
titanic.pivot_table?

# %%
titanic.groupby(['sex',age,'class'])['survived'].mean().unstack()
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %%
fare = pd.cut(titanic['fare'], [0, 20 ,1000])
titanic.pivot_table('survived', ['sex', age], [fare, 'class'])
# Out:
# fare            (0, 20]                     (20, 1000]
# class             First    Second     Third      First    Second     Third
# sex    age
# female (0, 18]      NaN  1.000000  0.666667   0.909091  1.000000  0.153846
#        (18, 80]     NaN  0.900000  0.478261   0.972973  0.900000  0.230769
# male   (0, 18]      NaN  0.428571  0.296296   0.800000  0.750000  0.125000
#        (18, 80]     0.0  0.094340  0.123656   0.391304  0.032258  0.250000

# %%
titanic.pivot_table(index='sex', columns='class',
                    aggfunc={'survived':sum, 'fare':'mean'})
# Out:
#               fare                       survived
# class        First     Second      Third    First Second Third
# sex
# female  106.125798  21.970121  16.118810       91     70    72
# male     67.226127  19.741782  12.661633       45     17    47

# %%
titanic.pivot_table('survived', index='sex', columns='class', aggfunc=sum,margins=True)
# Out:
# class   First  Second  Third  All
# sex
# female     91      70     72  233
# male       45      17     47  109
# All       136      87    119  342

# %%
births = pd.read_csv('births.csv')

# %%
births
# Out:
#        year  month   day gender  births
# 0      1969      1   1.0      F    4046
# 1      1969      1   1.0      M    4440
# 2      1969      1   2.0      F    4454
# 3      1969      1   2.0      M    4548
# 4      1969      1   3.0      F    4548
# 5      1969      1   3.0      M    4994
# 6      1969      1   4.0      F    4440
# 7      1969      1   4.0      M    4520
# 8      1969      1   5.0      F    4192
# 9      1969      1   5.0      M    4198
# 10     1969      1   6.0      F    4710
# 11     1969      1   6.0      M    4850
# 12     1969      1   7.0      F    4646
# 13     1969      1   7.0      M    5092
# 14     1969      1   8.0      F    4800
# 15     1969      1   8.0      M    4934
# 16     1969      1   9.0      F    4592
# 17     1969      1   9.0      M    4842
# 18     1969      1  10.0      F    4852
# 19     1969      1  10.0      M    5190
# 20     1969      1  11.0      F    4580
# 21     1969      1  11.0      M    4598
# ...

# %%
births['decade'] = 10 * (births['year'] // 10)
births.pivot_table('births', index='decade', columns='gender', aggfunc='sum')
#births
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
births.groupby(['decade','gender'])['births'].sum().unstack()
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set()  # use Seaborn styles
births.pivot_table('births', index='year', columns='gender', aggfunc='sum').plot()
#plt.ylabel('total births per year');

# %% [markdown]
# # Vectorized String Operations

# %%
x = np.array([2, 3, 5, 7, 11, 13])
x * 2
# Out:
# array([ 4,  6, 10, 14, 22, 26])

# %%
data = ['peter', 'Paul', 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ['Peter', 'Paul', 'Mary', 'Guido']

# %%
data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-3b0264c38d59> in <module>()
#       1 data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
# ----> 2 [s.capitalize() for s in data]
#
# <ipython-input-40-3b0264c38d59> in <listcomp>(.0)
#       1 data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
# ----> 2 [s.capitalize() for s in data]
#
# AttributeError: 'NoneType' object has no attribute 'capitalize'

# %%
names = pd.Series(data)
names
# Out:
# 0    peter
# 1     Paul
# 2     None
# 3     MARY
# 4    gUIDO
# dtype: object

# %%
names.str.upper()
# Out:
# 0    PETER
# 1     PAUL
# 2     None
# 3     MARY
# 4    GUIDO
# dtype: object

# %%
monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam',
                   'Eric Idle', 'Terry Jones', 'Michael Palin'])

# %%
monte.str.upper()
# Out:
# 0    GRAHAM CHAPMAN
# 1       JOHN CLEESE
# 2     TERRY GILLIAM
# 3         ERIC IDLE
# 4       TERRY JONES
# 5     MICHAEL PALIN
# dtype: object

# %%
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: object

# %%
a=monte.str.split()
a.iloc[0][1]
#a
# Out:
# 'Chapman'

# %%
full_monte = pd.DataFrame(data=['Graham Chapman', 'John Cleese', 'Terry Gilliam'],columns=['Name'])
full_monte
# Out:
#              Name
# 0  Graham Chapman
# 1     John Cleese
# 2   Terry Gilliam

# %%
full_monte['Last Name']=full_monte['Name'].str.extract('.*\s([a-zA-Z]+)',expand=False)
full_monte['Last Name']
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# Name: Last Name, dtype: object

# %%
full_monte['Last Name'].iloc[0]
# Out:
# 'Chapman'

# %%
a=full_monte['Name'].str.split()
a.iloc[0]=a.iloc[0][1]
a.iloc[1]=a.iloc[1][1]
a.iloc[2]=a.iloc[2][1]

# %%
a
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# Name: Name, dtype: object

# %%
full_monte['Last Name']=a
full_monte
# Out:
#              Name Last Name
# 0  Graham Chapman   Chapman
# 1     John Cleese    Cleese
# 2   Terry Gilliam   Gilliam

# %% [markdown]
# ![](string_vector.png)

# %%
monte.str.extract('.*\s([A-Za-z]+)', expand=False)
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# 3       Idle
# 4      Jones
# 5      Palin
# dtype: object

# %%
monte.str.findall(r'^[^AEIOU].*[^aeiou]$')
# Out:
# 0    [Graham Chapman]
# 1                  []
# 2     [Terry Gilliam]
# 3                  []
# 4       [Terry Jones]
# 5     [Michael Palin]
# dtype: object

# %%
monte.str.split().str.get(-1)
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# 3       Idle
# 4      Jones
# 5      Palin
# dtype: object

# %%
full_monte = pd.DataFrame({'name': monte,
                           'info': ['B|C|D', 'B|D', 'A|C',
                                    'B|D', 'B|C', 'B|C|D']})
full_monte
# Out:
#     info            name
# 0  B|C|D  Graham Chapman
# 1    B|D     John Cleese
# 2    A|C   Terry Gilliam
# 3    B|D       Eric Idle
# 4    B|C     Terry Jones
# 5  B|C|D   Michael Palin

# %%
full_monte['info'].str.get_dummies('|')
# Out:
#    A  B  C  D
# 0  0  1  1  1
# 1  0  1  0  1
# 2  1  0  1  0
# 3  0  1  0  1
# 4  0  1  1  0
# 5  0  1  1  1
